# %% [markdown]
# # Create Pipeline
# ## Connect to your workspace

# %%
import azureml.core
from azureml.core import Workspace

# Manualy define workspace config
# ws = Workspace.get(
#            name="webparsing",
#            subscription_id= "1e70b6a9-7079-4703-a282-0c52141550cc",
#            resource_group= "webparsing"
# )

# Load the workspace from the saved config file
ws = Workspace.from_config()
kv = ws.get_default_keyvault()

# %%
from azureml.core import Workspace
ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep = '\n')
# Out:
# Workspace name: webparsing_centralus
# Azure region: centralus
# Subscription id: 439243ce-aaee-42b7-82d8-c88d5a342df3
# Resource group: webparsing

# %% [markdown]
# ## Prepare a compute environment for the pipeline steps

# %%
# %ls
# Out:
# OlxParser_pipeline/        test_pipeline.ipynb.amltmp*
# OlxParser_pipeline_r05/    test_pipeline_r1.0.ipynb.amltmp*
# Test_pipeline.ipynb*       untitled.ipynb.amltmp*
# Test_pipeline_r1.0.ipynb*

# %%
# %cd code/Users/vadym.pakholchuk.sa60vadym.pakholchuk.sa60
# Out:
# /mnt/batch/tasks/shared/LS_root/mounts/clusters/olxcompute/code/Users/vadym.pakholchuk.sa60

# %%
import os

# Create a folder for the pipeline step files
experiment_folder = 'OlxParser_pipeline'
os.makedirs(experiment_folder, exist_ok=True)

print(experiment_folder)
# Out:
# OlxParser_pipeline

# %%
# get a secret from the keyvault
secret_name= kv.get_secret(name="BlobName")
secret_key = kv.get_secret(name="BlobKey")

# %%
# This block is needed to define Compute Target or create it, if we haven't it
from azureml.core.compute import ComputeTarget, AmlCompute
from azureml.core.compute_target import ComputeTargetException

cluster_name = "OLXCompute-v2"

try:
    # Check for existing compute target
    pipeline_cluster = ComputeTarget(workspace=ws, name=cluster_name)
    print('Found existing cluster, use it.')
    print(f'Cluster name: {cluster_name}')
except ComputeTargetException:
    # If it doesn't already exist, create it
    try:
        compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_DS11_V2', max_nodes=2)
        pipeline_cluster = ComputeTarget.create(ws, cluster_name, compute_config)
        pipeline_cluster.wait_for_completion(show_output=True)
    except Exception as ex:
        print(ex)
# Out:
# Found existing cluster, use it.
# Cluster name: OLXCompute-v2

# %%
from azureml.core import Environment
pipeline_env = Environment("OLX_Parsing")
pipeline_env.environment_variables['BLOB_ACCOUNTNAME'] = secret_name
pipeline_env.environment_variables['BLOB_ACCOUNT_KEY'] = secret_key
pipeline_env.environment_variables['BLOB_CONTAINER'] = 'olx'

# %%
# Set the container registry information.
# pipeline_env.docker.base_image_registry.address = "webparsingcontainer.azurecr.io"
# pipeline_env.docker.base_image_registry.username = "WebParsing"
# pipeline_env.docker.base_image_registry.password = "OvrOqNkqD5V8/EmeJcgBLbhMpYXvIX5S"

# %%
# When you're using your custom Docker image, you might already have your Python environment properly set up. 
# In that case, set the user_managed_dependencies flag to True to use your custom image's built-in Python environment.


# pipeline_env.docker.base_image = "webparsingcontainer.azurecr.io/web_parsing:v2"
pipeline_env.docker.base_image = "strateg17/web_parsing:v2"
pipeline_env.python.user_managed_dependencies = True

# %%
from azureml.core.runconfig import RunConfiguration

# Register the environment 
pipeline_env.register(workspace=ws)

registered_env = Environment.get(ws, 'OLX_Parsing')

# Create a new runconfig object for the pipeline
pipeline_run_config = RunConfiguration()

# Use the compute you created above. 
pipeline_run_config.target = pipeline_cluster

# Assign the environment to the run configuration
pipeline_run_config.environment = registered_env

print ("Run configuration created.")
# Out:
# Run configuration created.

# %% [markdown]
# ## Create and manage datastores for inputs and outputs

# %%
# from azureml.core.datastore import Datastore

# pages_datastore = Datastore.get(
#     workspace=ws, 
#     datastore_name="olx_pages_datastore")

# %% [markdown]
# ## Create and run a pipeline

# %%
from azureml.pipeline.core import PipelineData
from azureml.pipeline.steps import PythonScriptStep

pages_param_1 = PipelineData('pages',  is_directory=True)
images_param_1 = PipelineData('images', is_directory=True)

pages_param_2 = PipelineData('pages',  is_directory=True)
images_param_2 = PipelineData('images', is_directory=True)

# Find and save all first 25 pages step
write_output_step_1 = PythonScriptStep(
    name='The Page Saver for 25 pages',
    script_name='Step_1_OlxParser_azure.py',
    arguments = ["--pages-dir", pages_param_1],
    outputs=[pages_param_1],
    compute_target=pipeline_cluster,
    source_directory='OlxParser_pipeline',
    runconfig = pipeline_run_config,
    allow_reuse=False
)

# Parsing all available pages from the search result
read_output_step_1 = PythonScriptStep(
     name='The Page Parser of 25 pages',
    script_name='Step_2_OlxParser_azure.py',
    arguments = ["--pages-dir", pages_param_1, "--images-dir", images_param_1],
    inputs = [pages_param_1],
    outputs=[images_param_1],
    compute_target=pipeline_cluster,
    source_directory='OlxParser_pipeline',
    runconfig = pipeline_run_config,
    allow_reuse=False
)

# Validation of the status of all not processed today pages
status_validation_step = PythonScriptStep(
     name='The offer validation',
    script_name='Step_3_OlxParser_azure.py',
    compute_target=pipeline_cluster,
    source_directory='OlxParser_pipeline',
    runconfig = pipeline_run_config,
    allow_reuse=False
)

# Saving all not processed today pages
write_output_step_2 = PythonScriptStep(
    name='Active pages additional saving',
    script_name='Step_4_OlxParser_azure.py',
    arguments = ["--pages-dir", pages_param_2],
    outputs=[pages_param_2],
    compute_target=pipeline_cluster,
    source_directory='OlxParser_pipeline',
    runconfig = pipeline_run_config,
    allow_reuse=False
)

# Parsing all not processed today pages
read_output_step_2 = PythonScriptStep(
     name='Active pages additional parsing',
    script_name='Step_5_OlxParser_azure.py',
    arguments = ["--pages-dir", pages_param_2, "--images-dir", images_param_2],
    inputs = [pages_param_2],
    outputs=[images_param_2],
    compute_target=pipeline_cluster,
    source_directory='OlxParser_pipeline',
    runconfig = pipeline_run_config,
    allow_reuse=False
)

# %%
from azureml.core import Experiment
from azureml.pipeline.core import Pipeline, StepSequence

# Construct the pipeline
pipeline_steps = StepSequence(steps=[write_output_step_1, read_output_step_1, status_validation_step, write_output_step_2, read_output_step_2])
				  
pipeline = Pipeline(workspace=ws, steps=pipeline_steps)
print("Pipeline is built.")
# Out:
# Pipeline is built.

# %%
# Create an experiment and run the pipeline
experiment = Experiment(workspace=ws, name = 'OLX-parsing-pipeline')
pipeline_run = experiment.submit(pipeline, regenerate_outputs=True)
print("Pipeline submitted for execution.")
pipeline_run.wait_for_completion(show_output=True)
# Out:
# Created step The Page Saver for 25 pages [000e8bff][c1ac0a2c-583e-4f1e-bc1f-aefbe500ef05], (This step will run and generate new outputs)Created step The Page Parser of 25 pages [79a6ae9e][362c8640-89fd-4a08-9755-2dac31ec2445], (This step will run and generate new outputs)
#
# Created step The offer validation [fc7c21c1][6d196a85-9638-4ee4-bf0c-8f21a3944640], (This step will run and generate new outputs)Created step Active pages additional saving [253cae7f][c4a7a013-c698-4739-b71a-f565ced87125], (This step will run and generate new outputs)
# Created step Active pages additional parsing [f4a38287][57deb1db-effa-4c23-9b0c-250fee8a83c6], (This step will run and generate new outputs)
#
# Submitted PipelineRun 9128eff2-3daf-45ad-8b9c-7c2d8ff930d3
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/9128eff2-3daf-45ad-8b9c-7c2d8ff930d3?wsid=/subscriptions/439243ce-aaee-42b7-82d8-c88d5a342df3/resourcegroups/webparsing/workspaces/webparsing_centralus&tid=d41e8406-8169-4076-92b7-5301ec927b93
# Pipeline submitted for execution.
# PipelineRunId: 9128eff2-3daf-45ad-8b9c-7c2d8ff930d3
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/9128eff2-3daf-45ad-8b9c-7c2d8ff930d3?wsid=/subscriptions/439243ce-aaee-42b7-82d8-c88d5a342df3/resourcegroups/webparsing/workspaces/webparsing_centralus&tid=d41e8406-8169-4076-92b7-5301ec927b93
# PipelineRun Status: Running
#
#
# StepRunId: c1798ca7-54db-4c16-b43c-ab5eff165bc5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/c1798ca7-54db-4c16-b43c-ab5eff165bc5?wsid=/subscriptions/439243ce-aaee-42b7-82d8-c88d5a342df3/resourcegroups/webparsing/workspaces/webparsing_centralus&tid=d41e8406-8169-4076-92b7-5301ec927b93
# StepRun( The Page Saver for 25 pages ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d.txt
# ========================================================================================================================
# 2021-09-25T10:54:38Z Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24782 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# 2021-09-25T10:54:38Z Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore
# 2021-09-25T10:54:39Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-25T10:54:39Z Starting output-watcher...
# 2021-09-25T10:54:39Z IsDedicatedCompute == True, won't poll for Low Pri Preemption
# 2021-09-25T10:54:40Z Executing 'Copy ACR Details file' on 10.0.0.4
# 2021-09-25T10:54:40Z Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>
# >>>
# v2: Pulling from strateg17/web_parsing
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# 8edf37be41ad: Pulling fs layer
# deeb0ad9a00f: Pulling fs layer
# 6d129eb85d67: Pulling fs layer
# a13da2fad922: Pulling fs layer
# cdf54bc08d2f: Pulling fs layer
# 2f55168955fb: Pulling fs layer
# 108203a8cd9a: Pulling fs layer
# 89ad26c23a49: Pulling fs layer
# 6badf43c7132: Pulling fs layer
# 8edf37be41ad: Waiting
# deeb0ad9a00f: Waiting
# 6d129eb85d67: Waiting
# a13da2fad922: Waiting
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# cdf54bc08d2f: Waiting
# 2f55168955fb: Waiting
# 108203a8cd9a: Waiting
# 89ad26c23a49: Waiting
# 6badf43c7132: Waiting
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# feac53061382: Pull complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# 8edf37be41ad: Verifying Checksum
# 8edf37be41ad: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# 6d129eb85d67: Verifying Checksum
# 6d129eb85d67: Download complete
# a13da2fad922: Verifying Checksum
# a13da2fad922: Download complete
# cdf54bc08d2f: Verifying Checksum
# cdf54bc08d2f: Download complete
# 2f55168955fb: Verifying Checksum
# 2f55168955fb: Download complete
# 108203a8cd9a: Verifying Checksum
# 108203a8cd9a: Download complete
# 89ad26c23a49: Verifying Checksum
# 89ad26c23a49: Download complete
# 6badf43c7132: Verifying Checksum
# 6badf43c7132: Download complete
# deeb0ad9a00f: Verifying Checksum
# deeb0ad9a00f: Download complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# 8edf37be41ad: Pull complete
# deeb0ad9a00f: Pull complete
# 6d129eb85d67: Pull complete
# a13da2fad922: Pull complete
# cdf54bc08d2f: Pull complete
# 2f55168955fb: Pull complete
# 108203a8cd9a: Pull complete
# 89ad26c23a49: Pull complete
# 6badf43c7132: Pull complete
# Digest: sha256:458e972a2d2bc13ee1d11f6fc6abde33bb1f92b9ca355fa4a28a10929aff9d7d
# Status: Downloaded newer image for strateg17/web_parsing:v2
# docker.io/strateg17/web_parsing:v2
# 2021-09-25T10:55:06Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-25T10:55:06Z Check if container c1798ca7-54db-4c16-b43c-ab5eff165bc5 already exist exited with 0,
#
# bd05ca73ec0598b1c98af102b095d607a85e511846d51f15cf95c5d2fc07cbdf
# 2021-09-25T10:55:12Z Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# 2021-09-25T10:55:12Z containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-0de6c3ca20651cf12845e695433225a6-113f65d7b1f0d375-01 -sshRequired=false]
# 2021/09/25 10:55:12 Starting App Insight Logger for task:  containerSetup
# 2021/09/25 10:55:12 Version: 3.0.01727.0003 Branch: 2021-09-16+azure-notebooks+ci-mount-hf Commit: f9ec047
# 2021/09/25 10:55:12 Entered ContainerSetupTask - Preparing infiniband
# 2021/09/25 10:55:12 Starting infiniband setup
# 2021/09/25 10:55:12 Python Version found is Python 3.7.4
#
# 2021/09/25 10:55:12 Returning Python Version as 3.7
# 2021/09/25 10:55:13 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/09/25 10:55:13 VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021-09-25T10:55:13Z VMSize: standard_ds11_v2, Host: runtime-gen1-ubuntu18, Container: ubuntu-18.04
# 2021/09/25 10:55:13 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# 2021/09/25 10:55:13 Not setting up Infiniband in Container
# 2021/09/25 10:55:13 Not setting up Infiniband in Container
# 2021-09-25T10:55:13Z Not setting up Infiniband in Container
# 2021/09/25 10:55:13 Python Version found is Python 3.7.4
#
# 2021/09/25 10:55:13 Returning Python Version as 3.7
# 2021/09/25 10:55:13 sshd inside container not required for job, skipping setup.
# 2021/09/25 10:55:13 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# 2021/09/25 10:55:13 App Insight Client has already been closed
# 2021/09/25 10:55:13 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# Stopped: false
# OriginalData: 1
# FilteredData: 0.
# 2021-09-25T10:55:13Z Starting docker container succeeded.
# 2021-09-25T10:55:21Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-25T10:55:21Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-25T10:55:22Z Job environment preparation succeeded on 10.0.0.4. Output:
# >>>   2021/09/25 10:54:38 Starting App Insight Logger for task:  prepareJobEnvironment
# >>>   2021/09/25 10:54:38 Version: 3.0.01727.0003 Branch: 2021-09-16+azure-notebooks+ci-mount-hf Commit: f9ec047
# >>>   2021/09/25 10:54:38 runtime.GOOS linux
# >>>   2021/09/25 10:54:38 Checking if '/tmp' exists
# >>>   2021/09/25 10:54:38 Reading dyanamic configs
# >>>   2021/09/25 10:54:38 Container sas url: https://baiscriptsdm1prod.blob.core.windows.net/aihosttools?sv=2018-03-28&sr=c&si=aihosttoolspolicy&sig=0dYPjOcglC72KKRE2ILzFCKnPug7ECc2SIRWA3udLW0%3D
# >>>   2021/09/25 10:54:38 Failed to read from file /mnt/batch/tasks/startup/wd/az_resource/azsecpack.variables, open /mnt/batch/tasks/startup/wd/az_resource/azsecpack.variables: no such file or directory
# >>>   2021/09/25 10:54:38 [in autoUpgradeFromJobNodeSetup] Is Azsecpack installer on host: true. Is Azsecpack installation enabled: false,
# >>>   2021/09/25 10:54:38 Starting Azsecpack installation on machine: e4ed0eb35e9c4cd59269061e0f8a29e1000000#d41e8406-8169-4076-92b7-5301ec927b93#439243ce-aaee-42b7-82d8-c88d5a342df3#webparsing#webparsing_centralus#olxcompute-v2#tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d
# >>>   2021/09/25 10:54:38 Is Azsecpack enabled: false, GetDisableVsatlsscan: true
# >>>   2021/09/25 10:54:38 Turning off azsecpack, if it is already running
# >>>   2021/09/25 10:54:38 Start deleting Azsecpack installation cronjob...
# >>>   2021/09/25 10:54:38 Start checking if Azsecpack is running...
# >>>   2021/09/25 10:54:38 Azsecpack is not running. No need to stop Azsecpack processes.
# >>>   2021/09/25 10:54:38 DetonationChamber is not enabled on this subscription: 439243ce-aaee-42b7-82d8-c88d5a342df3
# >>>   2021/09/25 10:54:38 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:54:38 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:54:38 Get GPU count failed with err: The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.,
# >>>   2021/09/25 10:54:38 AMLComputeXDSEndpoint:  https://centralus.cert.api.azureml.ms/xdsbatchai
# >>>   2021/09/25 10:54:38 AMLComputeXDSApiVersion:  2018-02-01
# >>>   2021/09/25 10:54:38 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/config
# >>>   2021/09/25 10:54:38 This is not a aml-workstation (compute instance), current offer type: amlcompute. Starting identity responder as part of prepareJobEnvironment.
# >>>   2021/09/25 10:54:38 Starting identity responder.
# >>>   2021/09/25 10:54:38 Starting identity responder.
# >>>   2021/09/25 10:54:38 Logfile used for identity responder: /mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/IdentityResponderLog-tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d.txt
# >>>   2021/09/25 10:54:38 Logfile used for identity responder: /mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/IdentityResponderLog-tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d.txt
# >>>   2021/09/25 10:54:38 Started Identity Responder for job.
# >>>   2021/09/25 10:54:38 Started Identity Responder for job.
# >>>   2021/09/25 10:54:38 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd
# >>>   2021/09/25 10:54:38 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/shared
# >>>   2021/09/25 10:54:38 WorkingDirPath is specified. Setting env AZ_BATCHAI_JOB_WORK_DIR=$AZ_BATCHAI_JOB_TEMP/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:54:38 From the policy service, the filtering patterns is: , data store is
# >>>   2021/09/25 10:54:38 Mounting job level file systems
# >>>   2021/09/25 10:54:38 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts
# >>>   2021/09/25 10:54:38 Attempting to read datastore credentials file: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/config/.amlcompute.datastorecredentials
# >>>   2021/09/25 10:54:38 Datastore credentials file not found, skipping.
# >>>   2021/09/25 10:54:38 Attempting to read runtime sas tokens file: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/config/.master.runtimesastokens
# >>>   2021/09/25 10:54:38 Runtime sas tokens file not found, skipping.
# >>>   2021/09/25 10:54:38 NFS mount is not enabled
# >>>   2021/09/25 10:54:38 No Azure File Shares configured
# >>>   2021/09/25 10:54:38 Mounting blob file systems
# >>>   2021/09/25 10:54:38 Blobfuse runtime version 1.3.6
# >>>   2021/09/25 10:54:38 Mounting azureml-blobstore-10ff69f7-6f12-40e0-8de6-aff38bad2734 container from webparsing account at /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore
# >>>   2021/09/25 10:54:38 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/09/25 10:54:38 Using Compute Identity to authenticate Blobfuse: false.
# >>>   2021/09/25 10:54:38 Blobfuse cache size set to 24782 MB.
# >>>   2021/09/25 10:54:38 Running following command: /bin/bash -c sudo blobfuse /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore --tmp-path=/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/caches/workspaceblobstore --file-cache-timeout-in-seconds=1000000 --cache-size-mb=24782 -o nonempty -o allow_other --config-file=/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/configs/workspaceblobstore.cfg --log-level=LOG_WARNING
# >>>   2021/09/25 10:54:38 Successfully mounted a/an Blobfuse File System at /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore
# >>>   2021/09/25 10:54:38 Waiting for blobfs to be mounted at /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore
# >>>   2021/09/25 10:54:39 Successfully mounted azureml-blobstore-10ff69f7-6f12-40e0-8de6-aff38bad2734 container from webparsing account at /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore
# >>>   2021/09/25 10:54:39 Created run_id directory: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:54:39 No unmanaged file systems configured
# >>>   2021/09/25 10:54:39 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:54:39 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:54:39 WorkingDirPath is specified. Setting env AZ_BATCHAI_JOB_WORK_DIR=$AZ_BATCHAI_JOB_TEMP/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:54:39 From the policy service, the filtering patterns is: , data store is
# >>>   2021/09/25 10:54:39 Creating working directory: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:54:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:54:39 Changing permissions for all existing files under directory: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:54:39 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:54:39 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs
# >>>   2021/09/25 10:54:39 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs/tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d
# >>>   2021/09/25 10:54:39 Change mode to 666 for file /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs/tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d/55_azureml-execution-tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d.txt
# >>>   2021/09/25 10:54:39 Set default ACL for files under directory by running: /usr/bin/setfacl -m default:g::rwx -m default:o::rwx /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:54:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs
# >>>   2021/09/25 10:54:39 Changing permissions for all existing files under directory: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs
# >>>   2021/09/25 10:54:39 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs
# >>>   2021/09/25 10:54:39 Change mode to 777 for dir /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs/tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d
# >>>   2021/09/25 10:54:39 Change mode to 666 for file /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs/tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d/55_azureml-execution-tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d.txt
# >>>   2021/09/25 10:54:39 Set default ACL for files under directory by running: /usr/bin/setfacl -m default:g::rwx -m default:o::rwx /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs
# >>>   2021/09/25 10:54:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/logs
# >>>   2021/09/25 10:54:39 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/outputs
# >>>   2021/09/25 10:54:39 Starting output-watcher...
# >>>   2021/09/25 10:54:39 Single file input dataset is enabled.
# >>>   2021/09/25 10:54:39 SidecarEnabled:: isDetonationChamber: false, useDockerContainer: true
# >>>   2021/09/25 10:54:39 SidecarEnabled:: AmlDatasetContextManagerConfig exists: false
# >>>   2021/09/25 10:54:39 SidecarEnabled:: sidecar not enabled
# >>>   2021/09/25 10:54:39 Start to pulling docker image: strateg17/web_parsing:v2
# >>>   2021/09/25 10:54:39 Start pull docker image: strateg17
# >>>   2021/09/25 10:54:39 Getting credentials for image strateg17/web_parsing:v2 with url
# >>>   2021/09/25 10:54:39 Container registry is not ACR.
# >>>   2021/09/25 10:54:39 Skip getting ACR Credentials from Identity and will be getting it from EMS
# >>>   2021/09/25 10:54:39 Getting ACR Credentials from EMS for environment OLX_Parsing:1
# >>>   2021/09/25 10:54:39 Requesting XDS for registry details.
# >>>   2021/09/25 10:54:39 Attempt 1 of http call to https://centralus.cert.api.azureml.ms/xdsbatchai/hosttoolapi/subscriptions/439243ce-aaee-42b7-82d8-c88d5a342df3/resourceGroups/webparsing/workspaces/webparsing_centralus/clusters/olxcompute-v2/nodes/tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d?api-version=2018-02-01
# >>>   2021/09/25 10:54:40 Got container registry details from credentials service for registry address: .
# >>>   2021/09/25 10:54:40 Writing ACR Details to file...
# >>>   2021/09/25 10:54:40 Copying ACR Details file to worker nodes...
# >>>   2021/09/25 10:54:40 Executing 'Copy ACR Details file' on 10.0.0.4
# >>>   2021/09/25 10:54:40 Begin executing 'Copy ACR Details file' task on Node
# >>>   2021/09/25 10:54:40 'Copy ACR Details file' task Node result: succeeded
# >>>   2021/09/25 10:54:40 Copy ACR Details file succeeded on 10.0.0.4. Output:
# >>>   >>>
# >>>   >>>
# >>>   2021/09/25 10:54:40 EncryptedDockerRegistryPassword is empty.
# >>>   2021/09/25 10:54:40 EMS returned empty credentials for environment OLX_Parsing
# >>>   2021/09/25 10:54:40 Save docker credentials for image strateg17/web_parsing:v2 in /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/docker_login_3449502B5DAECC1B
# >>>   2021/09/25 10:54:40 The login info is empty, skipping login to the docker registry.
# >>>   2021/09/25 10:54:40 Start run pull docker image command
# >>>   2021/09/25 10:54:43 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 19
# >>>   FilteredData: 0.
# >>>   2021/09/25 10:55:06 Pull docker image succeeded.
# >>>   2021/09/25 10:55:06 Docker config dir /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/docker_login_3449502B5DAECC1B does not exist, skip removing it
# >>>   2021/09/25 10:55:06 Pull docker image time: 26.709494423s
# >>>
# >>>   2021/09/25 10:55:06 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/09/25 10:55:06 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:55:06 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:55:06 Setting the memory limit for docker container to be 13674 MB
# >>>   2021/09/25 10:55:06 The env variable file size is 40174 bytes
# >>>   2021/09/25 10:55:06 Creating parent cgroup 'c1798ca7-54db-4c16-b43c-ab5eff165bc5' for Containers used in Job
# >>>   2021/09/25 10:55:06 Add parent cgroup 'c1798ca7-54db-4c16-b43c-ab5eff165bc5' to container 'c1798ca7-54db-4c16-b43c-ab5eff165bc5'
# >>>   2021/09/25 10:55:06 /dev/infiniband/uverbs0 found (implying presence of InfiniBand)?: false
# >>>   2021/09/25 10:55:06 Original Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,c1798ca7-54db-4c16-b43c-ab5eff165bc5,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/certs:/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/certs,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-m,13674m,-v,/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs,-v,/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/wd:/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/wd,-v,/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5:/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5,-v,/mnt/batch/tasks/shared/LS_root/shared/tracing/c1798ca7-54db-4c16-b43c-ab5eff165bc5/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/c1798ca7-54db-4c16-b43c-ab5eff165bc5/logs/azureml/tracing,-w,/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/config/.batchai.envlist,--cgroup-parent=/c1798ca7-54db-4c16-b43c-ab5eff165bc5/,--shm-size,2g
# >>>   2021/09/25 10:55:06 the binding /mnt/batch/tasks/shared/LS_root/shared/tracing/c1798ca7-54db-4c16-b43c-ab5eff165bc5/logs/azureml/tracing:/mnt/batch/tasks/shared/LS_root/shared/tracing/c1798ca7-54db-4c16-b43c-ab5eff165bc5/logs/azureml/tracing is discarded as we already have /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared
# >>>   2021/09/25 10:55:06 the binding /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs:/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs is discarded as we already have /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5:/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:55:06 Updated Arguments: run,--ulimit,memlock=9223372036854775807,--ulimit,nofile=262144:262144,--cap-add,sys_ptrace,--name,c1798ca7-54db-4c16-b43c-ab5eff165bc5,-m,13674m,-w,/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd,--expose,23,--env-file,/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/config/.batchai.envlist,--cgroup-parent=/c1798ca7-54db-4c16-b43c-ab5eff165bc5/,--shm-size,2g,-v,/mnt/batch/tasks/startup:/mnt/batch/tasks/startup,-v,/mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared,-v,/mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared,-v,/mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs,-v,/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5:/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5,-v,/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/wd:/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/wd,-v,/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/certs:/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/certs
# >>>   2021/09/25 10:55:06 Running Docker command: docker run --ulimit memlock=9223372036854775807 --ulimit nofile=262144:262144 --cap-add sys_ptrace --name c1798ca7-54db-4c16-b43c-ab5eff165bc5 -m 13674m -w /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd --expose 23 --env-file /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/config/.batchai.envlist --cgroup-parent=/c1798ca7-54db-4c16-b43c-ab5eff165bc5/ --shm-size 2g -v /mnt/batch/tasks/startup:/mnt/batch/tasks/startup -v /mnt/batch/tasks/shared/LS_root/mounts:/mnt/batch/tasks/shared/LS_root/mounts:rshared -v /mnt/batch/tasks/shared/LS_root/shared:/mnt/batch/tasks/shared/LS_root/shared -v /mnt/batch/tasks/shared/LS_root/configs:/mnt/batch/tasks/shared/LS_root/configs -v /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5:/mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5 -v /mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/wd:/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/wd -v /mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/certs:/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/certs -d -it --privileged --net=host strateg17/web_parsing:v2
# >>>   2021/09/25 10:55:06 Check if container c1798ca7-54db-4c16-b43c-ab5eff165bc5 already exist exited with 0,
# >>>
# >>>   2021/09/25 10:55:06 Check if container c1798ca7-54db-4c16-b43c-ab5eff165bc5 already exist exited with 0,
# >>>
# >>>   2021/09/25 10:55:08 Attempt 1 of http call to https://centralus.api.azureml.ms/history/v1.0/private/subscriptions/439243ce-aaee-42b7-82d8-c88d5a342df3/resourceGroups/webparsing/providers/Microsoft.MachineLearningServices/workspaces/webparsing_centralus/runs/c1798ca7-54db-4c16-b43c-ab5eff165bc5/spans
# >>>   2021/09/25 10:55:12 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/09/25 10:55:12 Parameters for containerSetup task: useDetonationChamer set to false and sshRequired set to false
# >>>   2021/09/25 10:55:12 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-0de6c3ca20651cf12845e695433225a6-113f65d7b1f0d375-01 -sshRequired=false]
# >>>   2021/09/25 10:55:12 containerSetup task cmd: [/mnt/batch/tasks/startup/wd/hosttools -task=containerSetup -traceContext=00-0de6c3ca20651cf12845e695433225a6-113f65d7b1f0d375-01 -sshRequired=false]
# >>>   2021/09/25 10:55:13 Container ssh is not required for job type.
# >>>   2021/09/25 10:55:13 Starting docker container succeeded.
# >>>   2021/09/25 10:55:13 Starting docker container succeeded.
# >>>   2021/09/25 10:55:13 Disk space after starting docker container: 24400MB
# >>>   2021/09/25 10:55:13 SidecarEnabled:: isDetonationChamber: false, useDockerContainer: true
# >>>   2021/09/25 10:55:13 SidecarEnabled:: AmlDatasetContextManagerConfig exists: false
# >>>   2021/09/25 10:55:13 SidecarEnabled:: sidecar not enabled
# >>>   2021/09/25 10:55:13 Begin execution of runSpecialJobTask
# >>>   2021/09/25 10:55:13 Creating directory at $AZUREML_LOGDIRECTORY_PATH
# >>>   2021/09/25 10:55:13 Creating directory /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml-logs
# >>>   2021/09/25 10:55:13 runSpecialJobTask: checking control script content under dir: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5-setup
# >>>   2021/09/25 10:55:15 runSpecialJobTask: control script dir content: [_tracer.py: size=2022 md5=4c1dd974ef27d1cbec1434a93802ac73; _tracing.py: size=26407 md5=64b473943a5d2905628a9b2097f18081; _vendor_jwt_decode.py: size=2277 md5=d4b49e48ed904f03a4d6ad2f64f17368; azureml_globals.py: size=12242 md5=3700b728b132e633c956f368d13818e4; context_managers.py: size=48073 md5=1d499aa329dc1debda235d60098e98dd; job_prep.py: size=11214 md5=13bb64f32d440c1fbaff3644045668fc; log_history_status.py: size=4428 md5=778bbe2bb6cb72340d4344366f752a63; request_utilities.py: size=1185 md5=e053daf561ffebe1c54811d9dc11beaa; run_token_provider.py: size=4228 md5=b167c8697df9c999e3676723caa93cb3; utility_context_managers.py: size=5015 md5=824d969dee21cf92733986c744d17142]
# >>>   2021/09/25 10:55:15 runSpecialJobTask: os.GetEnv constants.StdouterrDir: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs
# >>>   2021/09/25 10:55:15 runSpecialJobTask: Raw cmd for preparation is passed is: python /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"44c603a2-1ded-4417-9675-aac798d77a68","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/09/25 10:55:15 runSpecialJobTask: stdout path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs/65_job_prep-tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d.txt
# >>>   2021/09/25 10:55:15 runSpecialJobTask: stderr path for preparation is passed is: /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/azureml_compute_logs/65_job_prep-tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d.txt
# >>>   2021/09/25 10:55:15 native cmd: export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5;python /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"44c603a2-1ded-4417-9675-aac798d77a68","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/09/25 10:55:15 runSpecialJobTask: commons.GetOsPlatform(): ubuntu
# >>>   2021/09/25 10:55:15 runSpecialJobTask: Running cmd: /usr/bin/docker exec -e AZUREML_SDK_TRACEPARENT=00-0de6c3ca20651cf12845e695433225a6-8335ba2964b91ec3-01 -t c1798ca7-54db-4c16-b43c-ab5eff165bc5 bash -c if [ -f ~/.bashrc ]; then PS1_back=$PS1; PS1='$'; . ~/.bashrc; PS1=$PS1_back; fi;PATH=$PATH:$AZ_BATCH_NODE_STARTUP_DIR/wd/;export AZUREML_JOB_TASK_ERROR_PATH='/mnt/batch/tasks/workitems/e755a242-539e-4e6b-b2df-7ef4bdffe33b/job-1/c1798ca7-54db-4c16-b_f62c7f9c-6090-4b78-b89e-528389cc2d2c/wd/runSpecialJobTask_error.json';cd /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/wd/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5;python /mnt/batch/tasks/shared/LS_root/jobs/webparsing_centralus/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5/mounts/workspaceblobstore/azureml/c1798ca7-54db-4c16-b43c-ab5eff165bc5-setup/job_prep.py -i DataStoreCopy:context_managers.DataStores --snapshots '[{"Id":"44c603a2-1ded-4417-9675-aac798d77a68","PathStack":["."],"SnapshotEntityId":null}]'
# >>>   2021/09/25 10:55:18 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 2
# >>>   FilteredData: 0.
# >>>   2021/09/25 10:55:21 containerName:c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:55:21 sidecar containerName:c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   2021/09/25 10:55:21 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/09/25 10:55:21 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:55:21 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:55:21 sidecar dockerLauncher:docker
# >>>   2021/09/25 10:55:21 sidecarContainerId:bd05ca73ec0598b1c98af102b095d607a85e511846d51f15cf95c5d2fc07cbdf
# >>>   2021/09/25 10:55:21 Docker Version that this nodes use are: 19.03.14+azure
# >>>
# >>>   2021/09/25 10:55:21 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:55:21 The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# >>>   2021/09/25 10:55:22 Docker logs for c1798ca7-54db-4c16-b43c-ab5eff165bc5
# >>>   Sep 25 10:55:12.865 [notice] Tor 0.3.2.10 (git-0edaa32732ec8930) running on Linux with Libevent 2.1.8-stable, OpenSSL 1.1.1, Zlib 1.2.11, Liblzma 5.2.2, and Libzstd 1.3.3.
# >>>   Sep 25 10:55:12.865 [notice] Tor can't help you if you use it wrong! Learn how to be safe at https://www.torproject.org/download/download#warning
# >>>   Sep 25 10:55:12.865 [notice] Read configuration file "/etc/tor/torrc".
# >>>   Sep 25 10:55:12.868 [notice] Scheduler type KIST has been enabled.
# >>>   Sep 25 10:55:12.868 [warn] You specified a public address '0.0.0.0:9050' for SocksPort. Other people on the Internet might find your computer and use it as an open proxy. Please don't allow this unless you have a good reason.
# >>>   Sep 25 10:55:12.868 [notice] Opening Socks listener on 0.0.0.0:9050
# >>>   Sep 25 10:55:12.868 [notice] Opening Control listener on 127.0.0.1:9051
# >>>   Sep 25 10:55:12.000 [notice] Parsing GEOIP IPv4 file /usr/share/tor/geoip.
# >>>   Sep 25 10:55:12.000 [notice] Parsing GEOIP IPv6 file /usr/share/tor/geoip6.
# >>>   Sep 25 10:55:12.000 [warn] You are running Tor as root. You don't need to, and you probably shouldn't.
# >>>   Sep 25 10:55:13.000 [notice] Bootstrapped 0%: Starting
# >>>   Sep 25 10:55:13.000 [notice] Starting with guard context "default"
# >>>   Sep 25 10:55:13.000 [notice] Bootstrapped 5%: Connecting to directory server
# >>>   Sep 25 10:55:15.000 [notice] Bootstrapped 10%: Finishing handshake with directory server
# >>>   Sep 25 10:55:15.000 [notice] Bootstrapped 15%: Establishing an encrypted directory connection
# >>>   Sep 25 10:55:15.000 [notice] Bootstrapped 20%: Asking for networkstatus consensus
# >>>   Sep 25 10:55:15.000 [notice] Bootstrapped 25%: Loading networkstatus consensus
# >>>   Sep 25 10:55:16.000 [notice] I learned some more directory information, but not enough to build a circuit: We have no usable consensus.
# >>>   Sep 25 10:55:16.000 [notice] Bootstrapped 40%: Loading authority key certs
# >>>   Sep 25 10:55:17.000 [notice] Bootstrapped 45%: Asking for relay descriptors
# >>>   Sep 25 10:55:17.000 [notice] I learned some more directory information, but not enough to build a circuit: We need more microdescriptors: we have 0/6834, and can only build 0% of likely paths. (We have 0% of guards bw, 0% of midpoint bw, and 0% of exit bw = 0% of path bw.)
# >>>   Sep 25 10:55:18.000 [notice] Bootstrapped 50%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 55%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 61%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 66%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 72%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 80%: Connecting to the Tor network
# >>>   Sep 25 10:55:20.000 [notice] Bootstrapped 85%: Finishing handshake with first hop
# >>>   Sep 25 10:55:21.000 [notice] Bootstrapped 90%: Establishing a Tor circuit
# >>>   Sep 25 10:55:21.000 [notice] Tor has successfully opened a circuit. Looks like client functionality is working.
# >>>   Sep 25 10:55:21.000 [notice] Bootstrapped 100%: Done
# >>>
# >>>   2021/09/25 10:55:22 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:16.123228] Entering job preparation.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.206764] Starting job preparation.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.206810] Extracting the control code.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.207194] Starting extract_project.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.207361] Starting to extract zip file.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.289695] Finished extracting zip file.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.292869] Using urllib.request Python 3.0 or later
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.292910] Start fetching snapshots.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.292940] Start fetching snapshot.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:19.292972] Retrieving project from snapshot: 44c603a2-1ded-4417-9675-aac798d77a68
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 35
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.141818] Finished fetching snapshot.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.141857] Finished fetching snapshots.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.141970] Finished extract_project.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.142083] Finished fetching and extracting the control code.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.145810] downloadDataStore - Download from datastores if requested.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.147277] Start run_history_prep.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.153300] Entering context manager injector.
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 2.7 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography<4.0.0,>=3.3.1; extra == "crypto"'), {'PyJWT'}).
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: Acquired lockfile /tmp/c1798ca7-54db-4c16-b43c-ab5eff165bc5-datastore.lock to downloading input data references
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.683303] downloadDataStore completed
# >>>   2021/09/25 10:55:22 runSpecialJobTask: preparation: [2021-09-25T10:55:21.686172] Job preparation is complete.
# >>>   2021/09/25 10:55:22 DockerSideCarContainerLogs:
# >>>   Sep 25 10:55:12.865 [notice] Tor 0.3.2.10 (git-0edaa32732ec8930) running on Linux with Libevent 2.1.8-stable, OpenSSL 1.1.1, Zlib 1.2.11, Liblzma 5.2.2, and Libzstd 1.3.3.
# >>>   Sep 25 10:55:12.865 [notice] Tor can't help you if you use it wrong! Learn how to be safe at https://www.torproject.org/download/download#warning
# >>>   Sep 25 10:55:12.865 [notice] Read configuration file "/etc/tor/torrc".
# >>>   Sep 25 10:55:12.868 [notice] Scheduler type KIST has been enabled.
# >>>   Sep 25 10:55:12.868 [warn] You specified a public address '0.0.0.0:9050' for SocksPort. Other people on the Internet might find your computer and use it as an open proxy. Please don't allow this unless you have a good reason.
# >>>   Sep 25 10:55:12.868 [notice] Opening Socks listener on 0.0.0.0:9050
# >>>   Sep 25 10:55:12.868 [notice] Opening Control listener on 127.0.0.1:9051
# >>>   Sep 25 10:55:12.000 [notice] Parsing GEOIP IPv4 file /usr/share/tor/geoip.
# >>>   Sep 25 10:55:12.000 [notice] Parsing GEOIP IPv6 file /usr/share/tor/geoip6.
# >>>   Sep 25 10:55:12.000 [warn] You are running Tor as root. You don't need to, and you probably shouldn't.
# >>>   Sep 25 10:55:13.000 [notice] Bootstrapped 0%: Starting
# >>>   Sep 25 10:55:13.000 [notice] Starting with guard context "default"
# >>>   Sep 25 10:55:13.000 [notice] Bootstrapped 5%: Connecting to directory server
# >>>   Sep 25 10:55:15.000 [notice] Bootstrapped 10%: Finishing handshake with directory server
# >>>   Sep 25 10:55:15.000 [notice] Bootstrapped 15%: Establishing an encrypted directory connection
# >>>   Sep 25 10:55:15.000 [notice] Bootstrapped 20%: Asking for networkstatus consensus
# >>>   Sep 25 10:55:15.000 [notice] Bootstrapped 25%: Loading networkstatus consensus
# >>>   Sep 25 10:55:16.000 [notice] I learned some more directory information, but not enough to build a circuit: We have no usable consensus.
# >>>   Sep 25 10:55:16.000 [notice] Bootstrapped 40%: Loading authority key certs
# >>>   Sep 25 10:55:17.000 [notice] Bootstrapped 45%: Asking for relay descriptors
# >>>   Sep 25 10:55:17.000 [notice] I learned some more directory information, but not enough to build a circuit: We need more microdescriptors: we have 0/6834, and can only build 0% of likely paths. (We have 0% of guards bw, 0% of midpoint bw, and 0% of exit bw = 0% of path bw.)
# >>>   Sep 25 10:55:18.000 [notice] Bootstrapped 50%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 55%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 61%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 66%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 72%: Loading relay descriptors
# >>>   Sep 25 10:55:19.000 [notice] Bootstrapped 80%: Connecting to the Tor network
# >>>   Sep 25 10:55:20.000 [notice] Bootstrapped 85%: Finishing handshake with first hop
# >>>   Sep 25 10:55:21.000 [notice] Bootstrapped 90%: Establishing a Tor circuit
# >>>   Sep 25 10:55:21.000 [notice] Tor has successfully opened a circuit. Looks like client functionality is working.
# >>>   Sep 25 10:55:21.000 [notice] Bootstrapped 100%: Done
# >>>
# >>>   2021/09/25 10:55:22 DockerSideCarContainerLogs End
# >>>   2021/09/25 10:55:22 Execution of runSpecialJobTask completed
# >>>   2021/09/25 10:55:22 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/09/25 10:55:22 Process Exiting with Code:  0
# >>>   2021/09/25 10:55:22 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# >>>
# 2021-09-25T10:55:22Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-25T10:55:22Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-25T10:55:22Z 127.0.0.1 slots=2 max-slots=2
# 2021-09-25T10:55:22Z launching Custom job
#
# Streaming azureml-logs/70_driver_log.txt
# ========================================
# ...
# >>>   Sep 25 12:49:40.627 [notice] Read configuration file "/etc/tor/torrc".
# >>>   Sep 25 12:49:40.630 [notice] Scheduler type KIST has been enabled.
# >>>   Sep 25 12:49:40.630 [warn] You specified a public address '0.0.0.0:9050' for SocksPort. Other people on the Internet might find your computer and use it as an open proxy. Please don't allow this unless you have a good reason.
# >>>   Sep 25 12:49:40.630 [notice] Opening Socks listener on 0.0.0.0:9050
# >>>   Sep 25 12:49:40.630 [notice] Opening Control listener on 127.0.0.1:9051
# >>>   Sep 25 12:49:40.000 [notice] Parsing GEOIP IPv4 file /usr/share/tor/geoip.
# >>>   Sep 25 12:49:40.000 [notice] Parsing GEOIP IPv6 file /usr/share/tor/geoip6.
# >>>   Sep 25 12:49:40.000 [warn] You are running Tor as root. You don't need to, and you probably shouldn't.
# >>>   Sep 25 12:49:40.000 [notice] Bootstrapped 0%: Starting
# >>>   Sep 25 12:49:40.000 [notice] Starting with guard context "default"
# >>>   Sep 25 12:49:41.000 [notice] Bootstrapped 5%: Connecting to directory server
# >>>   Sep 25 12:49:44.000 [notice] Bootstrapped 10%: Finishing handshake with directory server
# >>>   Sep 25 12:49:45.000 [notice] Bootstrapped 15%: Establishing an encrypted directory connection
# >>>   Sep 25 12:49:45.000 [notice] Bootstrapped 20%: Asking for networkstatus consensus
# >>>   Sep 25 12:49:45.000 [notice] Bootstrapped 25%: Loading networkstatus consensus
# >>>   Sep 25 12:49:47.000 [notice] I learned some more directory information, but not enough to build a circuit: We have no usable consensus.
# >>>   Sep 25 12:49:47.000 [notice] Bootstrapped 40%: Loading authority key certs
# >>>   Sep 25 12:49:47.000 [notice] Bootstrapped 45%: Asking for relay descriptors
# >>>   Sep 25 12:49:47.000 [notice] I learned some more directory information, but not enough to build a circuit: We need more microdescriptors: we have 0/6750, and can only build 0% of likely paths. (We have 0% of guards bw, 0% of midpoint bw, and 0% of exit bw = 0% of path bw.)
# >>>   Sep 25 12:49:48.000 [notice] Bootstrapped 50%: Loading relay descriptors
# >>>
# >>>   2021/09/25 12:49:49 runSpecialJobTask: job preparation exited with code 0 and err <nil>
# >>>
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:43.863829] Entering job preparation.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.664100] Starting job preparation.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.664137] Extracting the control code.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.664383] Starting extract_project.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.664424] Starting to extract zip file.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.769939] Finished extracting zip file.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.773404] Using urllib.request Python 3.0 or later
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.773444] Start fetching snapshots.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.773481] Start fetching snapshot.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:46.773494] Retrieving project from snapshot: 44c603a2-1ded-4417-9675-aac798d77a68
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: Starting the daemon thread to refresh tokens in background for process with pid = 36
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.292330] Finished fetching snapshot.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.292366] Finished fetching snapshots.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.292572] Finished extract_project.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.292744] Finished fetching and extracting the control code.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.297783] downloadDataStore - Download from datastores if requested.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.305086] Entering context manager injector.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.306214] Start run_history_prep.
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 2.7 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography<4.0.0,>=3.3.1; extra == "crypto"'), {'PyJWT'}).
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: Acquired lockfile /tmp/497bae43-bedd-4ccc-9be3-a268e6608694-datastore.lock to downloading input data references
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.840919] downloadDataStore completed
# >>>   2021/09/25 12:49:49 runSpecialJobTask: preparation: [2021-09-25T12:49:48.843741] Job preparation is complete.
# >>>   2021/09/25 12:49:49 DockerSideCarContainerLogs:
# >>>   Sep 25 12:49:40.627 [notice] Tor 0.3.2.10 (git-0edaa32732ec8930) running on Linux with Libevent 2.1.8-stable, OpenSSL 1.1.1, Zlib 1.2.11, Liblzma 5.2.2, and Libzstd 1.3.3.
# >>>   Sep 25 12:49:40.627 [notice] Tor can't help you if you use it wrong! Learn how to be safe at https://www.torproject.org/download/download#warning
# >>>   Sep 25 12:49:40.627 [notice] Read configuration file "/etc/tor/torrc".
# >>>   Sep 25 12:49:40.630 [notice] Scheduler type KIST has been enabled.
# >>>   Sep 25 12:49:40.630 [warn] You specified a public address '0.0.0.0:9050' for SocksPort. Other people on the Internet might find your computer and use it as an open proxy. Please don't allow this unless you have a good reason.
# >>>   Sep 25 12:49:40.630 [notice] Opening Socks listener on 0.0.0.0:9050
# >>>   Sep 25 12:49:40.630 [notice] Opening Control listener on 127.0.0.1:9051
# >>>   Sep 25 12:49:40.000 [notice] Parsing GEOIP IPv4 file /usr/share/tor/geoip.
# >>>   Sep 25 12:49:40.000 [notice] Parsing GEOIP IPv6 file /usr/share/tor/geoip6.
# >>>   Sep 25 12:49:40.000 [warn] You are running Tor as root. You don't need to, and you probably shouldn't.
# >>>   Sep 25 12:49:40.000 [notice] Bootstrapped 0%: Starting
# >>>   Sep 25 12:49:40.000 [notice] Starting with guard context "default"
# >>>   Sep 25 12:49:41.000 [notice] Bootstrapped 5%: Connecting to directory server
# >>>   Sep 25 12:49:44.000 [notice] Bootstrapped 10%: Finishing handshake with directory server
# >>>   Sep 25 12:49:45.000 [notice] Bootstrapped 15%: Establishing an encrypted directory connection
# >>>   Sep 25 12:49:45.000 [notice] Bootstrapped 20%: Asking for networkstatus consensus
# >>>   Sep 25 12:49:45.000 [notice] Bootstrapped 25%: Loading networkstatus consensus
# >>>   Sep 25 12:49:47.000 [notice] I learned some more directory information, but not enough to build a circuit: We have no usable consensus.
# >>>   Sep 25 12:49:47.000 [notice] Bootstrapped 40%: Loading authority key certs
# >>>   Sep 25 12:49:47.000 [notice] Bootstrapped 45%: Asking for relay descriptors
# >>>   Sep 25 12:49:47.000 [notice] I learned some more directory information, but not enough to build a circuit: We need more microdescriptors: we have 0/6750, and can only build 0% of likely paths. (We have 0% of guards bw, 0% of midpoint bw, and 0% of exit bw = 0% of path bw.)
# >>>   Sep 25 12:49:48.000 [notice] Bootstrapped 50%: Loading relay descriptors
# >>>
# >>>   2021/09/25 12:49:49 DockerSideCarContainerLogs End
# >>>   2021/09/25 12:49:49 Execution of runSpecialJobTask completed
# >>>   2021/09/25 12:49:49 Not exporting to RunHistory as the exporter is either stopped or there is no data.
# >>>   Stopped: false
# >>>   OriginalData: 3
# >>>   FilteredData: 0.
# >>>   2021/09/25 12:49:49 Process Exiting with Code:  0
# >>>   2021/09/25 12:49:49 All App Insights Logs was sent successfully or the close timeout of 10 was reached
# >>>
# 2021-09-25T12:49:49Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-25T12:49:49Z The vmsize standard_ds11_v2 is not a GPU VM, skipping get GPU count by running nvidia-smi command.
# 2021-09-25T12:49:49Z 127.0.0.1 slots=2 max-slots=2
# 2021-09-25T12:49:50Z launching Custom job
#
# Streaming azureml-logs/75_job_post-tvmps_2fdda137a9fa1770b71c45543cd6a3d0e0c9bc8b21c2d1f20ea9a25fdfa077ae_d.txt
# ===============================================================================================================
# [2021-09-25T12:50:06.086887] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (cryptography 2.7 (/opt/miniconda/lib/python3.7/site-packages), Requirement.parse('cryptography<4.0.0,>=3.3.1; extra == "crypto"'), {'PyJWT'}).
# [2021-09-25T12:50:06.926170] Starting job release
# [2021-09-25T12:50:06.926609] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 115
# [2021-09-25T12:50:06.927223] job release stage : upload_datastore starting...
# [2021-09-25T12:50:06.929466] Entering context manager injector.
# [2021-09-25T12:50:06.929690] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-09-25T12:50:06.936110] job release stage : execute_job_release starting...
# [2021-09-25T12:50:06.936390] job release stage : copy_batchai_cached_logs starting...
# [2021-09-25T12:50:06.938210] job release stage : copy_batchai_cached_logs completed...
# [2021-09-25T12:50:06.949079] job release stage : upload_datastore completed...
# [2021-09-25T12:50:07.000425] job release stage : send_run_telemetry starting...
# [2021-09-25T12:50:07.023787] get vm size and vm region successfully.
# [2021-09-25T12:50:07.047759] get compute meta data successfully.
# [2021-09-25T12:50:07.111005] job release stage : execute_job_release completed...
# [2021-09-25T12:50:07.327405] post artifact meta request successfully.
# [2021-09-25T12:50:07.441619] upload compute record artifact successfully.
# [2021-09-25T12:50:07.441737] job release stage : send_run_telemetry completed...
# [2021-09-25T12:50:07.442118] Job release is complete
#
# StepRun(Active pages additional parsing) Execution Summary
# ===========================================================
# StepRun( Active pages additional parsing ) Status: Finished
# {'runId': '497bae43-bedd-4ccc-9be3-a268e6608694', 'target': 'OLXCompute-v2', 'status': 'Completed', 'startTimeUtc': '2021-09-25T12:49:36.615043Z', 'endTimeUtc': '2021-09-25T12:50:15.68846Z', 'properties': {'ContentSnapshotId': '44c603a2-1ded-4417-9675-aac798d77a68', 'StepType': 'PythonScriptStep', 'ComputeTargetType': 'AmlCompute', 'azureml.moduleid': '57deb1db-effa-4c23-9b0c-250fee8a83c6', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'f4a38287', 'azureml.pipelinerunid': '9128eff2-3daf-45ad-8b9c-7c2d8ff930d3', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'amlcompute', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json'}, 'inputDatasets': [], 'outputDatasets': [], 'runDefinition': {'script': 'Step_5_OlxParser_azure.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--pages-dir', '$AZUREML_DATAREFERENCE_pages', '--images-dir', '$AZUREML_DATAREFERENCE_images'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'OLXCompute-v2', 'dataReferences': {'pages': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/23941cde-8c18-454d-bc91-e2f6326c2ac3/pages', 'pathOnCompute': None, 'overwrite': False}, 'images': {'dataStoreName': 'workspaceblobstore', 'mode': 'Mount', 'pathOnDataStore': 'azureml/497bae43-bedd-4ccc-9be3-a268e6608694/images', 'pathOnCompute': None, 'overwrite': False}}, 'data': {}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'OLX_Parsing', 'version': '1', 'python': {'interpreterPath': 'python', 'userManagedDependencies': True, 'condaDependencies': {'name': 'project_environment', 'dependencies': ['python=3.6.2', {'pip': ['azureml-defaults']}], 'channels': ['anaconda', 'conda-forge']}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE', 'BLOB_ACCOUNTNAME': 'webparsing', 'BLOB_ACCOUNT_KEY': '7M7zrUJxYLYAfIZ5/uyJQqrkqc5lD1lIOJXYVqKMEVH1xMNnsNs/WLNTeinnnSmH1/TR3+1MgW/9nqGXFpBLFg==', 'BLOB_CONTAINER': 'olx'}, 'docker': {'baseImage': 'strateg17/web_parsing:v2', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': False, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1, 'location': None}, 'aiSuperComputer': {'instanceType': 'AISupercomputer.D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': True, 'shmSize': '2g', 'arguments': []}, 'cmk8sCompute': {'configuration': {}}, 'commandReturnCodeConfig': {'returnCode': 'Zero', 'successfulReturnCodes': []}, 'environmentVariables': {}, 'applicationEndpoints ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': '9128eff2-3daf-45ad-8b9c-7c2d8ff930d3', 'status': 'Completed', 'startTimeUtc': '2021-09-25T10:51:55.287679Z', 'endTimeUtc': '2021-09-25T12:50:17.495355Z', 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://webparsing.blob.core.windows.net/azureml/ExperimentRun/dcid.9128eff2-3daf-45ad-8b9c-7c2d8ff930d3/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=iW16lq3Zd5cEpxNwmZfFL4i9x4li5BBpXu%2Bh%2BK8vtU0%3D&st=2021-09-25T12%3A40%3A19Z&se=2021-09-25T20%3A50%3A19Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://webparsing.blob.core.windows.net/azureml/ExperimentRun/dcid.9128eff2-3daf-45ad-8b9c-7c2d8ff930d3/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=hRC30UXVOawEDFfaLlOLdL663horpzitt50tnqOQWgs%3D&st=2021-09-25T12%3A40%3A19Z&se=2021-09-25T20%3A50%3A19Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://webparsing.blob.core.windows.net/azureml/ExperimentRun/dcid.9128eff2-3daf-45ad-8b9c-7c2d8ff930d3/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=DiknnyHBEpUfQ6qxYr1D%2BkTyaXtTyImdqYUMDrohzsU%3D&st=2021-09-25T12%3A40%3A19Z&se=2021-09-25T20%3A50%3A19Z&sp=r'}, 'submittedBy': 'Vadym Pakholchuk'}
# 'Finished'

# %% [markdown]
# ## Publish the pipeline

# %%
# Publish the pipeline from the run
published_pipeline = pipeline_run.publish_pipeline(
    name="olx-parsing-pipeline-v1", description="Retrive info from OLX", version="1.0")

published_pipeline
# Out:
# Pipeline(Name: olx-parsing-pipeline-v1,
# Id: f75da127-f000-45f1-93aa-d5529f90adf2,
# Status: Active,
# Endpoint: https://centralus.api.azureml.ms/pipelines/v1.0/subscriptions/439243ce-aaee-42b7-82d8-c88d5a342df3/resourceGroups/webparsing/providers/Microsoft.MachineLearningServices/workspaces/webparsing_centralus/PipelineRuns/PipelineSubmit/f75da127-f000-45f1-93aa-d5529f90adf2)

# %% [markdown]
# ## Schedule the Pipeline

# %%
from azureml.pipeline.core import ScheduleRecurrence, Schedule, TimeZone

# Submit the Pipeline every Day of the week at 01:00 UTC
recurrence = ScheduleRecurrence(frequency="Day", 
                                interval=1, 
                                time_of_day="00:15",
                                # time_zone=TimeZone.UTC02,
                                # start_time="2021-09-01T00:00:00"
                                )

daily_schedule = Schedule.create(ws, name="daily-olx-parser", 
                                  description="Based on time",
                                  pipeline_id='f75da127-f000-45f1-93aa-d5529f90adf2	', 
                                  experiment_name='OLX-parsing-pipeline', 
                                  recurrence=recurrence)
print('Pipeline scheduled.')
# Out:
# Pipeline scheduled.

# %%
import azureml.core
from azureml.core import Workspace
from azureml.pipeline.core import ScheduleRecurrence, Schedule

ws = Workspace.from_config()

ss = Schedule.list(ws)
for s in ss:
    print(s,'\n')
# Out:
# Pipeline(Name: daily-olx-parser,
# Id: 7a20a376-c30d-4853-968c-12e795e81ef4,
# Status: Active,
# Pipeline Id: f75da127-f000-45f1-93aa-d5529f90adf2	,
# Pipeline Endpoint Id: None,
# Recurrence Details: Runs at 0:15 every Day)

# %%
Schedule.get_schedules_for_pipeline_id(ws, '85845f92-757f-4b79-8458-3cd4c2643f29')
# Out:
# [Pipeline(Name: daily-olx-parser,
#  Id: 4a430931-e20c-4b49-8e93-097fa90bf5e2,
#  Status: Active,
#  Pipeline Id: 85845f92-757f-4b79-8458-3cd4c2643f29,
#  Pipeline Endpoint Id: None,
#  Recurrence Details: Runs at 0:5 every Day)]

# %%
sch = Schedule.get(ws, 'dc37f5a3-1b32-4b73-9d51-85fc0da6dd6a', _workflow_provider=None, _service_endpoint=None)

# %%
 Schedule.disable(sch)
